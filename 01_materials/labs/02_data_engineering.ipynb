# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2013-12-02   17.175102   19.686787   20.154642   19.672144   19.928572
# 2013-12-03   17.645264   20.225714   20.227858   19.917143   19.939285
# 2013-12-04   17.604137   20.178572   20.328215   20.029285   20.196428
# 2013-12-05   17.694496   20.282143   20.540714   20.228930   20.451786
# 2013-12-06   17.448978   20.000713   20.241072   19.984644   20.206785
# ...                ...         ...         ...         ...         ...
# 2024-01-25  193.223389  194.169998  196.270004  193.110001  195.220001
# 2024-01-26  191.481903  192.419998  194.759995  191.940002  194.270004
# 2024-01-29  190.795288  191.729996  192.199997  189.580002  192.009995
# 2024-01-30  187.123260  188.039993  191.800003  187.470001  190.940002
# 2024-01-31  183.501022  184.399994  187.100006  184.350006  187.039993
#
# Price          Volume
# Ticker           AAPL
# Date
# 2013-12-02  472544800
# 2013-12-03  450968000
# 2013-12-04  377809600
# 2013-12-05  447580000
# 2013-12-06  344352400
# ...               ...
# 2024-01-25   54822100
# 2024-01-26   44594000
# 2024-01-29   47145600
# 2024-01-30   55859400
# 2024-01-31   55467800
#
# [2558 rows x 6 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index()
# Out:
# Price        Date Ticker   Adj Close       Close        High         Low  \
# 0      2000-01-03   AAPL    0.843076    0.999442    1.004464    0.907924
# 1      2000-01-03    ACN         NaN         NaN         NaN         NaN
# 2      2000-01-03   ADBE   16.274672   16.390625   16.875000   16.062500
# 3      2000-01-03    ADI   28.095690   45.093750   46.937500   44.000000
# 4      2000-01-03   ADSK    8.052906    8.343750    8.656250    8.031250
# ...           ...    ...         ...         ...         ...         ...
# 403451 2025-01-24    TXN  184.158173  185.520004  191.500000  185.029999
# 403452 2025-01-24    TYL  591.929993  591.929993  594.969971  590.210022
# 403453 2025-01-24   VRSN  210.729996  210.729996  210.880005  206.009995
# 403454 2025-01-24    WDC   67.410004   67.410004   69.440002   67.360001
# 403455 2025-01-24   ZBRA  414.609985  414.609985  420.079987  413.739990
#
# Price         Open       Volume
# 0         0.936384  535796800.0
# 1              NaN          NaN
# 2        16.812500    7384400.0
# 3        46.750000    3655600.0
# 4         8.500000    2845600.0
# ...            ...          ...
# 403451  190.000000   15856600.0
# 403452  591.400024     155300.0
# 403453  206.020004     563300.0
# 403454   68.910004    6046500.0
# 403455  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 1.2395429611206055 seconds.
# Csv file size 41.361608 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 0.6323940753936768 seconds.
# Parquet file size 16.526370999999997 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /var/folders/d9/xy9lq_ws3bzg21vgl7rdtfbm0000gn/T/ipykernel_84158/3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                        ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                        ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(d11b178), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x16ccc7af0>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date   Adj Close       Close        High         Low        Open  \
# Ticker
# AAPL   2000-01-03    0.843076    0.999442    1.004464    0.907924    0.936384
# AAPL   2000-01-04    0.771997    0.915179    0.987723    0.903460    0.966518
# AAPL   2000-01-05    0.783293    0.928571    0.987165    0.919643    0.926339
# AAPL   2000-01-06    0.715509    0.848214    0.955357    0.848214    0.947545
# AAPL   2000-01-07    0.749401    0.888393    0.901786    0.852679    0.861607
# ...           ...         ...         ...         ...         ...         ...
# ZBRA   2025-01-17  405.709991  405.709991  407.290009  402.290009  406.040009
# ZBRA   2025-01-21  418.070007  418.070007  419.850006  407.619995  407.619995
# ZBRA   2025-01-22  420.570007  420.570007  427.760010  419.589996  425.239990
# ZBRA   2025-01-23  421.109985  421.109985  422.290009  414.450012  417.619995
# ZBRA   2025-01-24  414.609985  414.609985  420.079987  413.739990  419.059998
#
#              Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL    535796800.0  2000          NaN       NaN
# AAPL    512377600.0  2000     0.999442 -0.084310
# AAPL    778321600.0  2000     0.915179  0.014633
# AAPL    767972800.0  2000     0.928571 -0.086538
# AAPL    460734400.0  2000     0.848214  0.047369
# ...             ...   ...          ...       ...
# ZBRA       270600.0  2025   402.720001  0.007424
# ZBRA       446000.0  2025   405.709991  0.030465
# ZBRA       497500.0  2025   418.070007  0.005980
# ZBRA       377100.0  2025   420.570007  0.001284
# ZBRA       258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-02-02 19:50:03,825, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-02-02 19:50:03,827, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-02-02 19:50:03,832, data_manager.py, 57, INFO, Processing all tickers
# 2025-02-02 19:50:03,834, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-02-02 19:50:03,835, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-02-02
# [*********************100%***********************]  503 of 503 completed
#
# 7 Failed downloads:
# ['BRK.B', 'FLT', 'PEAK', 'WRK', 'PXD', 'MRO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-02-02)')
# 2025-02-02 19:50:34,825, data_manager.py, 80, INFO, Saving data by year
# 2025-02-02 19:50:34,943, data_manager.py, 83, INFO, Saving data for A
# 2025-02-02 19:50:35,203, data_manager.py, 83, INFO, Saving data for AAL
# 2025-02-02 19:50:35,455, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-02-02 19:50:35,725, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-02-02 19:50:35,981, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-02-02 19:50:36,223, data_manager.py, 83, INFO, Saving data for ABT
# 2025-02-02 19:50:36,466, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-02-02 19:50:36,714, data_manager.py, 83, INFO, Saving data for ACN
# 2025-02-02 19:50:36,969, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-02-02 19:50:37,238, data_manager.py, 83, INFO, Saving data for ADI
# 2025-02-02 19:50:37,516, data_manager.py, 83, INFO, Saving data for ADM
# 2025-02-02 19:50:37,778, data_manager.py, 83, INFO, Saving data for ADP
# 2025-02-02 19:50:38,036, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-02-02 19:50:38,330, data_manager.py, 83, INFO, Saving data for AEE
# 2025-02-02 19:50:38,594, data_manager.py, 83, INFO, Saving data for AEP
# 2025-02-02 19:50:38,860, data_manager.py, 83, INFO, Saving data for AES
# 2025-02-02 19:50:39,111, data_manager.py, 83, INFO, Saving data for AFL
# 2025-02-02 19:50:39,357, data_manager.py, 83, INFO, Saving data for AIG
# 2025-02-02 19:50:39,606, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-02-02 19:50:39,851, data_manager.py, 83, INFO, Saving data for AJG
# 2025-02-02 19:50:40,098, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-02-02 19:50:40,350, data_manager.py, 83, INFO, Saving data for ALB
# 2025-02-02 19:50:40,594, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-02-02 19:50:40,835, data_manager.py, 83, INFO, Saving data for ALL
# 2025-02-02 19:50:41,079, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-02-02 19:50:41,319, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-02-02 19:50:41,578, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-02-02 19:50:41,823, data_manager.py, 83, INFO, Saving data for AMD
# 2025-02-02 19:50:42,077, data_manager.py, 83, INFO, Saving data for AME
# 2025-02-02 19:50:42,322, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-02-02 19:50:42,564, data_manager.py, 83, INFO, Saving data for AMP
# 2025-02-02 19:50:42,808, data_manager.py, 83, INFO, Saving data for AMT
# 2025-02-02 19:50:43,053, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-02-02 19:50:43,296, data_manager.py, 83, INFO, Saving data for ANET
# 2025-02-02 19:50:43,545, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-02-02 19:50:43,797, data_manager.py, 83, INFO, Saving data for AON
# 2025-02-02 19:50:44,043, data_manager.py, 83, INFO, Saving data for AOS
# 2025-02-02 19:50:44,287, data_manager.py, 83, INFO, Saving data for APA
# 2025-02-02 19:50:44,534, data_manager.py, 83, INFO, Saving data for APD
# 2025-02-02 19:50:44,801, data_manager.py, 83, INFO, Saving data for APH
# 2025-02-02 19:50:45,061, data_manager.py, 83, INFO, Saving data for APTV
# 2025-02-02 19:50:45,302, data_manager.py, 83, INFO, Saving data for ARE
# 2025-02-02 19:50:45,545, data_manager.py, 83, INFO, Saving data for ATO
# 2025-02-02 19:50:45,791, data_manager.py, 83, INFO, Saving data for AVB
# 2025-02-02 19:50:46,035, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-02-02 19:50:46,290, data_manager.py, 83, INFO, Saving data for AVY
# 2025-02-02 19:50:46,538, data_manager.py, 83, INFO, Saving data for AWK
# 2025-02-02 19:50:46,783, data_manager.py, 83, INFO, Saving data for AXON
# 2025-02-02 19:50:47,026, data_manager.py, 83, INFO, Saving data for AXP
# 2025-02-02 19:50:47,269, data_manager.py, 83, INFO, Saving data for AZO
# 2025-02-02 19:50:47,515, data_manager.py, 83, INFO, Saving data for BA
# 2025-02-02 19:50:47,755, data_manager.py, 83, INFO, Saving data for BAC
# 2025-02-02 19:50:47,999, data_manager.py, 83, INFO, Saving data for BALL
# 2025-02-02 19:50:48,241, data_manager.py, 83, INFO, Saving data for BAX
# 2025-02-02 19:50:48,485, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-02-02 19:50:48,729, data_manager.py, 83, INFO, Saving data for BBY
# 2025-02-02 19:50:48,980, data_manager.py, 83, INFO, Saving data for BDX
# 2025-02-02 19:50:49,230, data_manager.py, 83, INFO, Saving data for BEN
# 2025-02-02 19:50:49,477, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-02-02 19:50:49,715, data_manager.py, 83, INFO, Saving data for BG
# 2025-02-02 19:50:49,955, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-02-02 19:50:50,195, data_manager.py, 83, INFO, Saving data for BIO
# 2025-02-02 19:50:50,439, data_manager.py, 83, INFO, Saving data for BK
# 2025-02-02 19:50:50,679, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-02-02 19:50:50,920, data_manager.py, 83, INFO, Saving data for BKR
# 2025-02-02 19:50:51,165, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-02-02 19:50:51,405, data_manager.py, 83, INFO, Saving data for BLK
# 2025-02-02 19:50:51,649, data_manager.py, 83, INFO, Saving data for BMY
# 2025-02-02 19:50:51,895, data_manager.py, 83, INFO, Saving data for BR
# 2025-02-02 19:50:52,135, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-02-02 19:50:52,372, data_manager.py, 83, INFO, Saving data for BRO
# 2025-02-02 19:50:52,615, data_manager.py, 83, INFO, Saving data for BSX
# 2025-02-02 19:50:52,857, data_manager.py, 83, INFO, Saving data for BWA
# 2025-02-02 19:50:53,112, data_manager.py, 83, INFO, Saving data for BX
# 2025-02-02 19:50:53,363, data_manager.py, 83, INFO, Saving data for BXP
# 2025-02-02 19:50:53,610, data_manager.py, 83, INFO, Saving data for C
# 2025-02-02 19:50:53,848, data_manager.py, 83, INFO, Saving data for CAG
# 2025-02-02 19:50:54,094, data_manager.py, 83, INFO, Saving data for CAH
# 2025-02-02 19:50:54,340, data_manager.py, 83, INFO, Saving data for CARR
# 2025-02-02 19:50:54,598, data_manager.py, 83, INFO, Saving data for CAT
# 2025-02-02 19:50:54,848, data_manager.py, 83, INFO, Saving data for CB
# 2025-02-02 19:50:55,089, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-02-02 19:50:55,328, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-02-02 19:50:55,570, data_manager.py, 83, INFO, Saving data for CCI
# 2025-02-02 19:50:55,815, data_manager.py, 83, INFO, Saving data for CCL
# 2025-02-02 19:50:56,065, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-02-02 19:50:56,319, data_manager.py, 83, INFO, Saving data for CDW
# 2025-02-02 19:50:56,577, data_manager.py, 83, INFO, Saving data for CE
# 2025-02-02 19:50:56,817, data_manager.py, 83, INFO, Saving data for CEG
# 2025-02-02 19:50:57,062, data_manager.py, 83, INFO, Saving data for CF
# 2025-02-02 19:50:57,303, data_manager.py, 83, INFO, Saving data for CFG
# 2025-02-02 19:50:57,546, data_manager.py, 83, INFO, Saving data for CHD
# 2025-02-02 19:50:57,794, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-02-02 19:50:58,036, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-02-02 19:50:58,277, data_manager.py, 83, INFO, Saving data for CI
# 2025-02-02 19:50:58,519, data_manager.py, 83, INFO, Saving data for CINF
# 2025-02-02 19:50:58,762, data_manager.py, 83, INFO, Saving data for CL
# 2025-02-02 19:50:59,005, data_manager.py, 83, INFO, Saving data for CLX
# 2025-02-02 19:50:59,251, data_manager.py, 83, INFO, Saving data for CMA
# 2025-02-02 19:50:59,496, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-02-02 19:50:59,737, data_manager.py, 83, INFO, Saving data for CME
# 2025-02-02 19:50:59,982, data_manager.py, 83, INFO, Saving data for CMG
# 2025-02-02 19:51:00,228, data_manager.py, 83, INFO, Saving data for CMI
# 2025-02-02 19:51:00,476, data_manager.py, 83, INFO, Saving data for CMS
# 2025-02-02 19:51:00,722, data_manager.py, 83, INFO, Saving data for CNC
# 2025-02-02 19:51:00,970, data_manager.py, 83, INFO, Saving data for CNP
# 2025-02-02 19:51:01,215, data_manager.py, 83, INFO, Saving data for COF
# 2025-02-02 19:51:01,466, data_manager.py, 83, INFO, Saving data for COO
# 2025-02-02 19:51:01,721, data_manager.py, 83, INFO, Saving data for COP
# 2025-02-02 19:51:01,992, data_manager.py, 83, INFO, Saving data for COR
# 2025-02-02 19:51:02,242, data_manager.py, 83, INFO, Saving data for COST
# 2025-02-02 19:51:02,484, data_manager.py, 83, INFO, Saving data for CPB
# 2025-02-02 19:51:02,730, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-02-02 19:51:02,973, data_manager.py, 83, INFO, Saving data for CPT
# 2025-02-02 19:51:03,218, data_manager.py, 83, INFO, Saving data for CRL
# 2025-02-02 19:51:03,462, data_manager.py, 83, INFO, Saving data for CRM
# 2025-02-02 19:51:03,717, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-02-02 19:51:03,979, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-02-02 19:51:04,224, data_manager.py, 83, INFO, Saving data for CSX
# 2025-02-02 19:51:04,469, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-02-02 19:51:04,710, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-02-02 19:51:04,952, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-02-02 19:51:05,192, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-02-02 19:51:05,445, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-02-02 19:51:05,690, data_manager.py, 83, INFO, Saving data for CVS
# 2025-02-02 19:51:05,934, data_manager.py, 83, INFO, Saving data for CVX
# 2025-02-02 19:51:06,181, data_manager.py, 83, INFO, Saving data for CZR
# 2025-02-02 19:51:06,424, data_manager.py, 83, INFO, Saving data for D
# 2025-02-02 19:51:06,663, data_manager.py, 83, INFO, Saving data for DAL
# 2025-02-02 19:51:06,908, data_manager.py, 83, INFO, Saving data for DAY
# 2025-02-02 19:51:07,151, data_manager.py, 83, INFO, Saving data for DD
# 2025-02-02 19:51:07,392, data_manager.py, 83, INFO, Saving data for DE
# 2025-02-02 19:51:07,633, data_manager.py, 83, INFO, Saving data for DFS
# 2025-02-02 19:51:07,879, data_manager.py, 83, INFO, Saving data for DG
# 2025-02-02 19:51:08,119, data_manager.py, 83, INFO, Saving data for DGX
# 2025-02-02 19:51:08,363, data_manager.py, 83, INFO, Saving data for DHI
# 2025-02-02 19:51:08,608, data_manager.py, 83, INFO, Saving data for DHR
# 2025-02-02 19:51:08,858, data_manager.py, 83, INFO, Saving data for DIS
# 2025-02-02 19:51:09,108, data_manager.py, 83, INFO, Saving data for DLR
# 2025-02-02 19:51:09,353, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-02-02 19:51:09,596, data_manager.py, 83, INFO, Saving data for DOV
# 2025-02-02 19:51:09,842, data_manager.py, 83, INFO, Saving data for DOW
# 2025-02-02 19:51:10,111, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-02-02 19:51:10,360, data_manager.py, 83, INFO, Saving data for DRI
# 2025-02-02 19:51:10,624, data_manager.py, 83, INFO, Saving data for DTE
# 2025-02-02 19:51:10,881, data_manager.py, 83, INFO, Saving data for DUK
# 2025-02-02 19:51:11,128, data_manager.py, 83, INFO, Saving data for DVA
# 2025-02-02 19:51:11,374, data_manager.py, 83, INFO, Saving data for DVN
# 2025-02-02 19:51:11,623, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-02-02 19:51:11,866, data_manager.py, 83, INFO, Saving data for EA
# 2025-02-02 19:51:12,106, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-02-02 19:51:12,350, data_manager.py, 83, INFO, Saving data for ECL
# 2025-02-02 19:51:12,595, data_manager.py, 83, INFO, Saving data for ED
# 2025-02-02 19:51:12,835, data_manager.py, 83, INFO, Saving data for EFX
# 2025-02-02 19:51:13,078, data_manager.py, 83, INFO, Saving data for EG
# 2025-02-02 19:51:13,317, data_manager.py, 83, INFO, Saving data for EIX
# 2025-02-02 19:51:13,562, data_manager.py, 83, INFO, Saving data for EL
# 2025-02-02 19:51:13,803, data_manager.py, 83, INFO, Saving data for ELV
# 2025-02-02 19:51:14,048, data_manager.py, 83, INFO, Saving data for EMN
# 2025-02-02 19:51:14,293, data_manager.py, 83, INFO, Saving data for EMR
# 2025-02-02 19:51:14,537, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-02-02 19:51:14,789, data_manager.py, 83, INFO, Saving data for EOG
# 2025-02-02 19:51:15,035, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-02-02 19:51:15,288, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-02-02 19:51:15,534, data_manager.py, 83, INFO, Saving data for EQR
# 2025-02-02 19:51:15,781, data_manager.py, 83, INFO, Saving data for EQT
# 2025-02-02 19:51:16,024, data_manager.py, 83, INFO, Saving data for ES
# 2025-02-02 19:51:16,265, data_manager.py, 83, INFO, Saving data for ESS
# 2025-02-02 19:51:16,510, data_manager.py, 83, INFO, Saving data for ETN
# 2025-02-02 19:51:16,755, data_manager.py, 83, INFO, Saving data for ETR
# 2025-02-02 19:51:17,001, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-02-02 19:51:17,242, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-02-02 19:51:17,494, data_manager.py, 83, INFO, Saving data for EW
# 2025-02-02 19:51:17,738, data_manager.py, 83, INFO, Saving data for EXC
# 2025-02-02 19:51:17,981, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-02-02 19:51:18,224, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-02-02 19:51:18,466, data_manager.py, 83, INFO, Saving data for EXR
# 2025-02-02 19:51:18,713, data_manager.py, 83, INFO, Saving data for F
# 2025-02-02 19:51:18,954, data_manager.py, 83, INFO, Saving data for FANG
# 2025-02-02 19:51:19,194, data_manager.py, 83, INFO, Saving data for FAST
# 2025-02-02 19:51:19,491, data_manager.py, 83, INFO, Saving data for FCX
# 2025-02-02 19:51:19,739, data_manager.py, 83, INFO, Saving data for FDS
# 2025-02-02 19:51:19,990, data_manager.py, 83, INFO, Saving data for FDX
# 2025-02-02 19:51:20,233, data_manager.py, 83, INFO, Saving data for FE
# 2025-02-02 19:51:20,473, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-02-02 19:51:20,727, data_manager.py, 83, INFO, Saving data for FI
# 2025-02-02 19:51:20,969, data_manager.py, 83, INFO, Saving data for FICO
# 2025-02-02 19:51:21,224, data_manager.py, 83, INFO, Saving data for FIS
# 2025-02-02 19:51:21,470, data_manager.py, 83, INFO, Saving data for FITB
# 2025-02-02 19:51:21,713, data_manager.py, 83, INFO, Saving data for FLT
# 2025-02-02 19:51:21,957, data_manager.py, 83, INFO, Saving data for FMC
# 2025-02-02 19:51:22,202, data_manager.py, 83, INFO, Saving data for FOX
# 2025-02-02 19:51:22,447, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-02-02 19:51:22,687, data_manager.py, 83, INFO, Saving data for FRT
# 2025-02-02 19:51:22,931, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-02-02 19:51:23,184, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-02-02 19:51:23,441, data_manager.py, 83, INFO, Saving data for FTV
# 2025-02-02 19:51:23,684, data_manager.py, 83, INFO, Saving data for GD
# 2025-02-02 19:51:23,926, data_manager.py, 83, INFO, Saving data for GE
# 2025-02-02 19:51:24,166, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-02-02 19:51:24,405, data_manager.py, 83, INFO, Saving data for GEN
# 2025-02-02 19:51:24,664, data_manager.py, 83, INFO, Saving data for GILD
# 2025-02-02 19:51:24,908, data_manager.py, 83, INFO, Saving data for GIS
# 2025-02-02 19:51:25,154, data_manager.py, 83, INFO, Saving data for GL
# 2025-02-02 19:51:25,428, data_manager.py, 83, INFO, Saving data for GLW
# 2025-02-02 19:51:25,688, data_manager.py, 83, INFO, Saving data for GM
# 2025-02-02 19:51:25,933, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-02-02 19:51:26,173, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-02-02 19:51:26,414, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-02-02 19:51:26,679, data_manager.py, 83, INFO, Saving data for GPC
# 2025-02-02 19:51:26,926, data_manager.py, 83, INFO, Saving data for GPN
# 2025-02-02 19:51:27,170, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-02-02 19:51:27,413, data_manager.py, 83, INFO, Saving data for GS
# 2025-02-02 19:51:27,654, data_manager.py, 83, INFO, Saving data for GWW
# 2025-02-02 19:51:27,900, data_manager.py, 83, INFO, Saving data for HAL
# 2025-02-02 19:51:28,145, data_manager.py, 83, INFO, Saving data for HAS
# 2025-02-02 19:51:28,389, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-02-02 19:51:28,631, data_manager.py, 83, INFO, Saving data for HCA
# 2025-02-02 19:51:28,875, data_manager.py, 83, INFO, Saving data for HD
# 2025-02-02 19:51:29,116, data_manager.py, 83, INFO, Saving data for HES
# 2025-02-02 19:51:29,360, data_manager.py, 83, INFO, Saving data for HIG
# 2025-02-02 19:51:29,606, data_manager.py, 83, INFO, Saving data for HII
# 2025-02-02 19:51:29,850, data_manager.py, 83, INFO, Saving data for HLT
# 2025-02-02 19:51:30,101, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-02-02 19:51:30,343, data_manager.py, 83, INFO, Saving data for HON
# 2025-02-02 19:51:30,588, data_manager.py, 83, INFO, Saving data for HPE
# 2025-02-02 19:51:30,844, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-02-02 19:51:31,118, data_manager.py, 83, INFO, Saving data for HRL
# 2025-02-02 19:51:31,365, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-02-02 19:51:31,637, data_manager.py, 83, INFO, Saving data for HST
# 2025-02-02 19:51:31,884, data_manager.py, 83, INFO, Saving data for HSY
# 2025-02-02 19:51:32,128, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-02-02 19:51:32,370, data_manager.py, 83, INFO, Saving data for HUM
# 2025-02-02 19:51:32,616, data_manager.py, 83, INFO, Saving data for HWM
# 2025-02-02 19:51:32,859, data_manager.py, 83, INFO, Saving data for IBM
# 2025-02-02 19:51:33,119, data_manager.py, 83, INFO, Saving data for ICE
# 2025-02-02 19:51:33,366, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-02-02 19:51:33,606, data_manager.py, 83, INFO, Saving data for IEX
# 2025-02-02 19:51:33,849, data_manager.py, 83, INFO, Saving data for IFF
# 2025-02-02 19:51:34,094, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-02-02 19:51:34,336, data_manager.py, 83, INFO, Saving data for INCY
# 2025-02-02 19:51:34,579, data_manager.py, 83, INFO, Saving data for INTC
# 2025-02-02 19:51:34,833, data_manager.py, 83, INFO, Saving data for INTU
# 2025-02-02 19:51:35,091, data_manager.py, 83, INFO, Saving data for INVH
# 2025-02-02 19:51:35,333, data_manager.py, 83, INFO, Saving data for IP
# 2025-02-02 19:51:35,574, data_manager.py, 83, INFO, Saving data for IPG
# 2025-02-02 19:51:35,817, data_manager.py, 83, INFO, Saving data for IQV
# 2025-02-02 19:51:36,060, data_manager.py, 83, INFO, Saving data for IR
# 2025-02-02 19:51:36,325, data_manager.py, 83, INFO, Saving data for IRM
# 2025-02-02 19:51:36,573, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-02-02 19:51:36,813, data_manager.py, 83, INFO, Saving data for IT
# 2025-02-02 19:51:37,066, data_manager.py, 83, INFO, Saving data for ITW
# 2025-02-02 19:51:37,314, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-02-02 19:51:37,593, data_manager.py, 83, INFO, Saving data for J
# 2025-02-02 19:51:37,834, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-02-02 19:51:38,077, data_manager.py, 83, INFO, Saving data for JBL
# 2025-02-02 19:51:38,336, data_manager.py, 83, INFO, Saving data for JCI
# 2025-02-02 19:51:38,582, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-02-02 19:51:38,833, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-02-02 19:51:39,080, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-02-02 19:51:39,335, data_manager.py, 83, INFO, Saving data for JPM
# 2025-02-02 19:51:39,580, data_manager.py, 83, INFO, Saving data for K
# 2025-02-02 19:51:39,819, data_manager.py, 83, INFO, Saving data for KDP
# 2025-02-02 19:51:40,062, data_manager.py, 83, INFO, Saving data for KEY
# 2025-02-02 19:51:40,308, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-02-02 19:51:40,560, data_manager.py, 83, INFO, Saving data for KHC
# 2025-02-02 19:51:40,802, data_manager.py, 83, INFO, Saving data for KIM
# 2025-02-02 19:51:41,047, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-02-02 19:51:41,301, data_manager.py, 83, INFO, Saving data for KMB
# 2025-02-02 19:51:41,573, data_manager.py, 83, INFO, Saving data for KMI
# 2025-02-02 19:51:41,819, data_manager.py, 83, INFO, Saving data for KMX
# 2025-02-02 19:51:42,062, data_manager.py, 83, INFO, Saving data for KO
# 2025-02-02 19:51:42,301, data_manager.py, 83, INFO, Saving data for KR
# 2025-02-02 19:51:42,545, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-02-02 19:51:42,785, data_manager.py, 83, INFO, Saving data for L
# 2025-02-02 19:51:43,026, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-02-02 19:51:43,268, data_manager.py, 83, INFO, Saving data for LEN
# 2025-02-02 19:51:43,547, data_manager.py, 83, INFO, Saving data for LH
# 2025-02-02 19:51:43,794, data_manager.py, 83, INFO, Saving data for LHX
# 2025-02-02 19:51:44,040, data_manager.py, 83, INFO, Saving data for LIN
# 2025-02-02 19:51:44,285, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-02-02 19:51:44,529, data_manager.py, 83, INFO, Saving data for LLY
# 2025-02-02 19:51:44,775, data_manager.py, 83, INFO, Saving data for LMT
# 2025-02-02 19:51:45,029, data_manager.py, 83, INFO, Saving data for LNT
# 2025-02-02 19:51:45,277, data_manager.py, 83, INFO, Saving data for LOW
# 2025-02-02 19:51:45,525, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-02-02 19:51:45,781, data_manager.py, 83, INFO, Saving data for LULU
# 2025-02-02 19:51:46,022, data_manager.py, 83, INFO, Saving data for LUV
# 2025-02-02 19:51:46,265, data_manager.py, 83, INFO, Saving data for LVS
# 2025-02-02 19:51:46,507, data_manager.py, 83, INFO, Saving data for LW
# 2025-02-02 19:51:46,748, data_manager.py, 83, INFO, Saving data for LYB
# 2025-02-02 19:51:46,993, data_manager.py, 83, INFO, Saving data for LYV
# 2025-02-02 19:51:47,238, data_manager.py, 83, INFO, Saving data for MA
# 2025-02-02 19:51:47,479, data_manager.py, 83, INFO, Saving data for MAA
# 2025-02-02 19:51:47,723, data_manager.py, 83, INFO, Saving data for MAR
# 2025-02-02 19:51:47,970, data_manager.py, 83, INFO, Saving data for MAS
# 2025-02-02 19:51:48,214, data_manager.py, 83, INFO, Saving data for MCD
# 2025-02-02 19:51:48,460, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-02-02 19:51:48,714, data_manager.py, 83, INFO, Saving data for MCK
# 2025-02-02 19:51:48,970, data_manager.py, 83, INFO, Saving data for MCO
# 2025-02-02 19:51:49,215, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-02-02 19:51:49,458, data_manager.py, 83, INFO, Saving data for MDT
# 2025-02-02 19:51:49,733, data_manager.py, 83, INFO, Saving data for MET
# 2025-02-02 19:51:49,980, data_manager.py, 83, INFO, Saving data for META
# 2025-02-02 19:51:50,220, data_manager.py, 83, INFO, Saving data for MGM
# 2025-02-02 19:51:50,467, data_manager.py, 83, INFO, Saving data for MHK
# 2025-02-02 19:51:50,711, data_manager.py, 83, INFO, Saving data for MKC
# 2025-02-02 19:51:50,957, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-02-02 19:51:51,199, data_manager.py, 83, INFO, Saving data for MLM
# 2025-02-02 19:51:51,446, data_manager.py, 83, INFO, Saving data for MMC
# 2025-02-02 19:51:51,715, data_manager.py, 83, INFO, Saving data for MMM
# 2025-02-02 19:51:51,964, data_manager.py, 83, INFO, Saving data for MNST
# 2025-02-02 19:51:52,206, data_manager.py, 83, INFO, Saving data for MO
# 2025-02-02 19:51:52,447, data_manager.py, 83, INFO, Saving data for MOH
# 2025-02-02 19:51:52,691, data_manager.py, 83, INFO, Saving data for MOS
# 2025-02-02 19:51:52,936, data_manager.py, 83, INFO, Saving data for MPC
# 2025-02-02 19:51:53,181, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-02-02 19:51:53,435, data_manager.py, 83, INFO, Saving data for MRK
# 2025-02-02 19:51:53,680, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-02-02 19:51:53,920, data_manager.py, 83, INFO, Saving data for MRO
# 2025-02-02 19:51:54,165, data_manager.py, 83, INFO, Saving data for MS
# 2025-02-02 19:51:54,405, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-02-02 19:51:54,645, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-02-02 19:51:54,900, data_manager.py, 83, INFO, Saving data for MSI
# 2025-02-02 19:51:55,162, data_manager.py, 83, INFO, Saving data for MTB
# 2025-02-02 19:51:55,407, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-02-02 19:51:55,680, data_manager.py, 83, INFO, Saving data for MTD
# 2025-02-02 19:51:55,929, data_manager.py, 83, INFO, Saving data for MU
# 2025-02-02 19:51:56,184, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-02-02 19:51:56,425, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-02-02 19:51:56,667, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-02-02 19:51:56,910, data_manager.py, 83, INFO, Saving data for NEE
# 2025-02-02 19:51:57,155, data_manager.py, 83, INFO, Saving data for NEM
# 2025-02-02 19:51:57,401, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-02-02 19:51:57,642, data_manager.py, 83, INFO, Saving data for NI
# 2025-02-02 19:51:57,888, data_manager.py, 83, INFO, Saving data for NKE
# 2025-02-02 19:51:58,135, data_manager.py, 83, INFO, Saving data for NOC
# 2025-02-02 19:51:58,380, data_manager.py, 83, INFO, Saving data for NOW
# 2025-02-02 19:51:58,638, data_manager.py, 83, INFO, Saving data for NRG
# 2025-02-02 19:51:58,886, data_manager.py, 83, INFO, Saving data for NSC
# 2025-02-02 19:51:59,132, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-02-02 19:51:59,387, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-02-02 19:51:59,628, data_manager.py, 83, INFO, Saving data for NUE
# 2025-02-02 19:51:59,876, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-02-02 19:52:00,162, data_manager.py, 83, INFO, Saving data for NVR
# 2025-02-02 19:52:00,409, data_manager.py, 83, INFO, Saving data for NWS
# 2025-02-02 19:52:00,654, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-02-02 19:52:00,891, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-02-02 19:52:01,172, data_manager.py, 83, INFO, Saving data for O
# 2025-02-02 19:52:01,414, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-02-02 19:52:01,685, data_manager.py, 83, INFO, Saving data for OKE
# 2025-02-02 19:52:01,931, data_manager.py, 83, INFO, Saving data for OMC
# 2025-02-02 19:52:02,177, data_manager.py, 83, INFO, Saving data for ON
# 2025-02-02 19:52:02,428, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-02-02 19:52:02,685, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-02-02 19:52:02,928, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-02-02 19:52:03,168, data_manager.py, 83, INFO, Saving data for OXY
# 2025-02-02 19:52:03,413, data_manager.py, 83, INFO, Saving data for PANW
# 2025-02-02 19:52:03,668, data_manager.py, 83, INFO, Saving data for PARA
# 2025-02-02 19:52:03,909, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-02-02 19:52:04,148, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-02-02 19:52:04,391, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-02-02 19:52:04,631, data_manager.py, 83, INFO, Saving data for PCG
# 2025-02-02 19:52:04,874, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-02-02 19:52:05,113, data_manager.py, 83, INFO, Saving data for PEG
# 2025-02-02 19:52:05,357, data_manager.py, 83, INFO, Saving data for PEP
# 2025-02-02 19:52:05,603, data_manager.py, 83, INFO, Saving data for PFE
# 2025-02-02 19:52:05,849, data_manager.py, 83, INFO, Saving data for PFG
# 2025-02-02 19:52:06,095, data_manager.py, 83, INFO, Saving data for PG
# 2025-02-02 19:52:06,336, data_manager.py, 83, INFO, Saving data for PGR
# 2025-02-02 19:52:06,589, data_manager.py, 83, INFO, Saving data for PH
# 2025-02-02 19:52:06,835, data_manager.py, 83, INFO, Saving data for PHM
# 2025-02-02 19:52:07,082, data_manager.py, 83, INFO, Saving data for PKG
# 2025-02-02 19:52:07,332, data_manager.py, 83, INFO, Saving data for PLD
# 2025-02-02 19:52:07,611, data_manager.py, 83, INFO, Saving data for PM
# 2025-02-02 19:52:07,853, data_manager.py, 83, INFO, Saving data for PNC
# 2025-02-02 19:52:08,100, data_manager.py, 83, INFO, Saving data for PNR
# 2025-02-02 19:52:08,345, data_manager.py, 83, INFO, Saving data for PNW
# 2025-02-02 19:52:08,594, data_manager.py, 83, INFO, Saving data for PODD
# 2025-02-02 19:52:08,842, data_manager.py, 83, INFO, Saving data for POOL
# 2025-02-02 19:52:09,085, data_manager.py, 83, INFO, Saving data for PPG
# 2025-02-02 19:52:09,334, data_manager.py, 83, INFO, Saving data for PPL
# 2025-02-02 19:52:09,587, data_manager.py, 83, INFO, Saving data for PRU
# 2025-02-02 19:52:09,835, data_manager.py, 83, INFO, Saving data for PSA
# 2025-02-02 19:52:10,082, data_manager.py, 83, INFO, Saving data for PSX
# 2025-02-02 19:52:10,329, data_manager.py, 83, INFO, Saving data for PTC
# 2025-02-02 19:52:10,618, data_manager.py, 83, INFO, Saving data for PWR
# 2025-02-02 19:52:10,870, data_manager.py, 83, INFO, Saving data for PXD
# 2025-02-02 19:52:11,113, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-02-02 19:52:11,355, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-02-02 19:52:11,612, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-02-02 19:52:11,867, data_manager.py, 83, INFO, Saving data for RCL
# 2025-02-02 19:52:12,114, data_manager.py, 83, INFO, Saving data for REG
# 2025-02-02 19:52:12,359, data_manager.py, 83, INFO, Saving data for REGN
# 2025-02-02 19:52:12,603, data_manager.py, 83, INFO, Saving data for RF
# 2025-02-02 19:52:12,843, data_manager.py, 83, INFO, Saving data for RHI
# 2025-02-02 19:52:13,089, data_manager.py, 83, INFO, Saving data for RJF
# 2025-02-02 19:52:13,335, data_manager.py, 83, INFO, Saving data for RL
# 2025-02-02 19:52:13,578, data_manager.py, 83, INFO, Saving data for RMD
# 2025-02-02 19:52:13,858, data_manager.py, 83, INFO, Saving data for ROK
# 2025-02-02 19:52:14,106, data_manager.py, 83, INFO, Saving data for ROL
# 2025-02-02 19:52:14,354, data_manager.py, 83, INFO, Saving data for ROP
# 2025-02-02 19:52:14,614, data_manager.py, 83, INFO, Saving data for ROST
# 2025-02-02 19:52:14,857, data_manager.py, 83, INFO, Saving data for RSG
# 2025-02-02 19:52:15,101, data_manager.py, 83, INFO, Saving data for RTX
# 2025-02-02 19:52:15,345, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-02-02 19:52:15,586, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-02-02 19:52:15,828, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-02-02 19:52:16,070, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-02-02 19:52:16,312, data_manager.py, 83, INFO, Saving data for SHW
# 2025-02-02 19:52:16,557, data_manager.py, 83, INFO, Saving data for SJM
# 2025-02-02 19:52:16,801, data_manager.py, 83, INFO, Saving data for SLB
# 2025-02-02 19:52:17,046, data_manager.py, 83, INFO, Saving data for SNA
# 2025-02-02 19:52:17,291, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-02-02 19:52:17,545, data_manager.py, 83, INFO, Saving data for SO
# 2025-02-02 19:52:17,786, data_manager.py, 83, INFO, Saving data for SPG
# 2025-02-02 19:52:18,032, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-02-02 19:52:18,274, data_manager.py, 83, INFO, Saving data for SRE
# 2025-02-02 19:52:18,518, data_manager.py, 83, INFO, Saving data for STE
# 2025-02-02 19:52:18,764, data_manager.py, 83, INFO, Saving data for STLD
# 2025-02-02 19:52:19,007, data_manager.py, 83, INFO, Saving data for STT
# 2025-02-02 19:52:19,250, data_manager.py, 83, INFO, Saving data for STX
# 2025-02-02 19:52:19,508, data_manager.py, 83, INFO, Saving data for STZ
# 2025-02-02 19:52:19,788, data_manager.py, 83, INFO, Saving data for SWK
# 2025-02-02 19:52:20,035, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-02-02 19:52:20,299, data_manager.py, 83, INFO, Saving data for SYF
# 2025-02-02 19:52:20,567, data_manager.py, 83, INFO, Saving data for SYK
# 2025-02-02 19:52:20,821, data_manager.py, 83, INFO, Saving data for SYY
# 2025-02-02 19:52:21,069, data_manager.py, 83, INFO, Saving data for T
# 2025-02-02 19:52:21,309, data_manager.py, 83, INFO, Saving data for TAP
# 2025-02-02 19:52:21,555, data_manager.py, 83, INFO, Saving data for TDG
# 2025-02-02 19:52:21,801, data_manager.py, 83, INFO, Saving data for TDY
# 2025-02-02 19:52:22,062, data_manager.py, 83, INFO, Saving data for TECH
# 2025-02-02 19:52:22,304, data_manager.py, 83, INFO, Saving data for TEL
# 2025-02-02 19:52:22,562, data_manager.py, 83, INFO, Saving data for TER
# 2025-02-02 19:52:22,823, data_manager.py, 83, INFO, Saving data for TFC
# 2025-02-02 19:52:23,068, data_manager.py, 83, INFO, Saving data for TFX
# 2025-02-02 19:52:23,312, data_manager.py, 83, INFO, Saving data for TGT
# 2025-02-02 19:52:23,558, data_manager.py, 83, INFO, Saving data for TJX
# 2025-02-02 19:52:23,804, data_manager.py, 83, INFO, Saving data for TMO
# 2025-02-02 19:52:24,048, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-02-02 19:52:24,289, data_manager.py, 83, INFO, Saving data for TPR
# 2025-02-02 19:52:24,534, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-02-02 19:52:24,773, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-02-02 19:52:25,030, data_manager.py, 83, INFO, Saving data for TROW
# 2025-02-02 19:52:25,281, data_manager.py, 83, INFO, Saving data for TRV
# 2025-02-02 19:52:25,528, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-02-02 19:52:25,801, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-02-02 19:52:26,041, data_manager.py, 83, INFO, Saving data for TSN
# 2025-02-02 19:52:26,286, data_manager.py, 83, INFO, Saving data for TT
# 2025-02-02 19:52:26,526, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-02-02 19:52:26,768, data_manager.py, 83, INFO, Saving data for TXN
# 2025-02-02 19:52:27,028, data_manager.py, 83, INFO, Saving data for TXT
# 2025-02-02 19:52:27,275, data_manager.py, 83, INFO, Saving data for TYL
# 2025-02-02 19:52:27,537, data_manager.py, 83, INFO, Saving data for UAL
# 2025-02-02 19:52:27,783, data_manager.py, 83, INFO, Saving data for UBER
# 2025-02-02 19:52:28,022, data_manager.py, 83, INFO, Saving data for UDR
# 2025-02-02 19:52:28,268, data_manager.py, 83, INFO, Saving data for UHS
# 2025-02-02 19:52:28,511, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-02-02 19:52:28,751, data_manager.py, 83, INFO, Saving data for UNH
# 2025-02-02 19:52:28,997, data_manager.py, 83, INFO, Saving data for UNP
# 2025-02-02 19:52:29,242, data_manager.py, 83, INFO, Saving data for UPS
# 2025-02-02 19:52:29,488, data_manager.py, 83, INFO, Saving data for URI
# 2025-02-02 19:52:29,731, data_manager.py, 83, INFO, Saving data for USB
# 2025-02-02 19:52:30,002, data_manager.py, 83, INFO, Saving data for V
# 2025-02-02 19:52:30,242, data_manager.py, 83, INFO, Saving data for VFC
# 2025-02-02 19:52:30,492, data_manager.py, 83, INFO, Saving data for VICI
# 2025-02-02 19:52:30,730, data_manager.py, 83, INFO, Saving data for VLO
# 2025-02-02 19:52:30,976, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-02-02 19:52:31,218, data_manager.py, 83, INFO, Saving data for VMC
# 2025-02-02 19:52:31,464, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-02-02 19:52:31,710, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-02-02 19:52:32,001, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-02-02 19:52:32,250, data_manager.py, 83, INFO, Saving data for VTR
# 2025-02-02 19:52:32,497, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-02-02 19:52:32,749, data_manager.py, 83, INFO, Saving data for VZ
# 2025-02-02 19:52:32,991, data_manager.py, 83, INFO, Saving data for WAB
# 2025-02-02 19:52:33,238, data_manager.py, 83, INFO, Saving data for WAT
# 2025-02-02 19:52:33,485, data_manager.py, 83, INFO, Saving data for WBA
# 2025-02-02 19:52:33,730, data_manager.py, 83, INFO, Saving data for WBD
# 2025-02-02 19:52:33,974, data_manager.py, 83, INFO, Saving data for WDC
# 2025-02-02 19:52:34,234, data_manager.py, 83, INFO, Saving data for WEC
# 2025-02-02 19:52:34,482, data_manager.py, 83, INFO, Saving data for WELL
# 2025-02-02 19:52:34,723, data_manager.py, 83, INFO, Saving data for WFC
# 2025-02-02 19:52:34,969, data_manager.py, 83, INFO, Saving data for WHR
# 2025-02-02 19:52:35,213, data_manager.py, 83, INFO, Saving data for WM
# 2025-02-02 19:52:35,454, data_manager.py, 83, INFO, Saving data for WMB
# 2025-02-02 19:52:35,697, data_manager.py, 83, INFO, Saving data for WMT
# 2025-02-02 19:52:35,945, data_manager.py, 83, INFO, Saving data for WRB
# 2025-02-02 19:52:36,191, data_manager.py, 83, INFO, Saving data for WRK
# 2025-02-02 19:52:36,435, data_manager.py, 83, INFO, Saving data for WST
# 2025-02-02 19:52:36,678, data_manager.py, 83, INFO, Saving data for WTW
# 2025-02-02 19:52:36,919, data_manager.py, 83, INFO, Saving data for WY
# 2025-02-02 19:52:37,161, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-02-02 19:52:37,401, data_manager.py, 83, INFO, Saving data for XEL
# 2025-02-02 19:52:37,645, data_manager.py, 83, INFO, Saving data for XOM
# 2025-02-02 19:52:37,919, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-02-02 19:52:38,189, data_manager.py, 83, INFO, Saving data for XYL
# 2025-02-02 19:52:38,435, data_manager.py, 83, INFO, Saving data for YUM
# 2025-02-02 19:52:38,718, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-02-02 19:52:38,963, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-02-02 19:52:39,223, data_manager.py, 83, INFO, Saving data for ZION
# 2025-02-02 19:52:39,467, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-02-02 19:52:46,998, data_manager.py, 114, INFO, Creating features data.
# 2025-02-02 19:52:47,000, data_manager.py, 124, INFO, Loading price data from ../../05_src/data/prices/
# 2025-02-02 19:52:47,845, data_manager.py, 133, INFO, Creating features
# /Users/sumiaya/Desktop/DS Course Projects/Week 9 & 10 - Production/assignment-1/production/01_materials/labs/../../05_src/data_manager.py:136: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('Ticker', group_keys=False)
# 2025-02-02 19:52:47,848, data_manager.py, 158, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
